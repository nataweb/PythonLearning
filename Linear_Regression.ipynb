# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
data = pd.read_csv('cost_revenue_clean.csv')
data.describe()
# Out:
#        production_budge_usd  wordwide_gross_usd
# count          5.033000e+03        5.033000e+03
# mean           3.291418e+07        9.517576e+07
# std            4.112751e+07        1.726131e+08
# min            1.100000e+03        4.010000e+02
# 25%            6.000000e+06        7.000000e+06
# 50%            1.900000e+07        3.296865e+07
# 75%            4.200000e+07        1.034529e+08
# max            4.250000e+08        2.783919e+09

# %%
X = pd.DataFrame(data, columns=['production_budge_usd'])
y = pd.DataFrame(data, columns=['wordwide_gross_usd'])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.xlim(0, 450000000)
plt.ylabel('Wordwide Gross  $')
plt.ylim(0, 3000000000)

plt.show()

# %% [markdown]
# **Linear Regression**

# %%
regression = LinearRegression()
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
#slope coefficient
regression.coef_
# Out:
# array([[3.11152465]])

# %%
regression.intercept_
# Out:
# array([-7237521.30517444])

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, alpha=0.3)
plt.plot(X, regression.predict(X), color="red", linewidth=4)
plt.title('Film Cost vs Global Revenue')
plt.xlabel('Production Budget $')
plt.xlim(0, 450000000)
plt.ylabel('Wordwide Gross  $')
plt.ylim(0, 3000000000)

plt.show()

# %%
regression.score(X, y)
# Out:
# 0.5496214454226855
